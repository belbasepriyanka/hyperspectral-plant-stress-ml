# %% [markdown]
# # AI Dragon Fruit Disease Scouting & Risk Dashboard
# Synthetic hyperspectral demonstration only — not a diagnosis.

# %%
from src.data_generation import generate_demo
from src.modeling import evaluate_models, pca_projection, healthy_anomaly
df = generate_demo()
df.shape

# %%
metrics, importance, predictions, cm, labels, features = evaluate_models(df)
pca, variance = pca_projection(df)
risk = healthy_anomaly(df)
metrics
